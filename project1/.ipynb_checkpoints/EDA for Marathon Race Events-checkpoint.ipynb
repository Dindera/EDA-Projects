# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import plotly.express as px

plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', 500)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
# Out:
# C:\Users\chide\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# C:\Users\chide\AppData\Local\Temp\ipykernel_14184\640688336.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Get the data
df = pd.read_csv('Data/TWO_CENTURIES_OF_UM_RACES.csv')
# Out:
# C:\Users\chide\AppData\Local\Temp\ipykernel_14184\4143378476.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Data/TWO_CENTURIES_OF_UM_RACES.csv')

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# 1                         22           5:15:45 h   Roberto Echeverría
# 2                         22           5:16:44 h    Puro Trail Osorno
# 3                         22           5:34:13 h             Columbia
# 4                         22           5:54:14 h       Baguales Trail
# 5                         22           6:25:01 h                  NaN
# 6                         22           6:28:00 h        Los Patagones
# 7                         22           6:32:24 h       Reaktiva Chile
# 8                         22           6:39:08 h    Puro Trail Osorno
# 9                         22           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4
# 5                 7.792           5
# 6                 7.732           6
# 7                 7.645           7
# 8                 7.516           8
# 9                 7.404           9

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
# Clean up Data

# %%
# Only get UK Races, 50k, 2020

# Show 50mi or 50k data

# %%
df[df['Event distance/length'] == '50mi']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                                ...                   ...
# 7461181               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461182               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461183               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461184               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461185               Avalon Benefit 50-Mile Run (USA)                  50mi
#
#          Event number of finishers Athlete performance      Athlete club  \
# 55                               9           9:53:05 h  *Middleville, MI
# 56                               9          11:09:35 h     *Waterloo, ON
# 57                               9          11:33:00 h    *Kitchener, ON
# 58                               9          11:38:17 h        *Utica, MI
# 59                               9          11:56:35 h   *Grass Lake, MI
# ...                            ...                 ...               ...
# 7461181                         92          11:59:37 h               NaN
# 7461182                         92          12:01:41 h               NaN
# 7461183                         92          12:03:26 h               NaN
# 7461184                         92          12:03:26 h               NaN
# 7461185                         92          12:05:59 h               NaN
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 55                  USA                 1983.0              M
# 56                  CAN                 1977.0              F
# 57                  CAN                 1976.0              M
# 58                  USA                 1986.0              M
# 59                  USA                 1988.0              M
# ...                 ...                    ...            ...
# 7461181             USA                 1941.0              M
# 7461182             USA                 1932.0              M
# 7461183             USA                 1934.0              F
# 7461184             USA                 1951.0              F
# 7461185             USA                 1947.0              F
#
#         Athlete age category Athlete average speed  Athlete ID
# 55                       M23                 8.141          55
# 56                       W40                 7.211          56
# 57                       M40                 6.967          57
# 58                       M23                 6.914          58
# 59                       M23                 6.738          59
# ...                      ...                   ...         ...
# 7461181                  M50                6709.0     1045603
# 7461182                  M60                6690.0     1070463
# 7461183                  W60                6674.0      416139
# 7461184                  W40                6674.0     1098098
# 7461185                  W45                6650.0     1626367
#
# [352181 rows x 13 columns]

# %%
# combine 50km/50mi with isin

# %%
df[df['Event distance/length'].isin(['50km', '50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 0                        50km                         22           4:51:39 h
# 1                        50km                         22           5:15:45 h
# 2                        50km                         22           5:16:44 h
# 3                        50km                         22           5:34:13 h
# 4                        50km                         22           5:54:14 h
# ...                       ...                        ...                 ...
# 7461181                  50mi                         92          11:59:37 h
# 7461182                  50mi                         92          12:01:41 h
# 7461183                  50mi                         92          12:03:26 h
# 7461184                  50mi                         92          12:03:26 h
# 7461185                  50mi                         92          12:05:59 h
#
#                Athlete club Athlete country  Athlete year of birth  \
# 0                     Tnfrc             CHI                 1978.0
# 1        Roberto Echeverría             CHI                 1981.0
# 2         Puro Trail Osorno             CHI                 1987.0
# 3                  Columbia             ARG                 1976.0
# 4            Baguales Trail             CHI                 1992.0
# ...                     ...             ...                    ...
# 7461181                 NaN             USA                 1941.0
# 7461182                 NaN             USA                 1932.0
# 7461183                 NaN             USA                 1934.0
# 7461184                 NaN             USA                 1951.0
# 7461185                 NaN             USA                 1947.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                    M                  M35                10.286           0
# 1                    M                  M35                 9.501           1
# 2                    M                  M23                 9.472           2
# 3                    M                  M40                 8.976           3
# 4                    M                  M23                 8.469           4
# ...                ...                  ...                   ...         ...
# 7461181              M                  M50                6709.0     1045603
# 7461182              M                  M60                6690.0     1070463
# 7461183              F                  W60                6674.0      416139
# 7461184              F                  W40                6674.0     1098098
# 7461185              F                  W45                6650.0     1626367
#
# [1874790 rows x 13 columns]

# %%
df[(df['Event distance/length'].isin(['50km', '50mi'])) & df['Year of event'].isin([2020, 2021, 2022])]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 3609801           2022      16.10.2022
# 3609802           2022      16.10.2022
# 3609803           2022      16.10.2022
# 3609804           2022      16.10.2022
# 3609805           2022      16.10.2022
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...                                          ...                   ...
# 3609801       Tussey Mountainback 50 Miler (USA)                  50mi
# 3609802       Tussey Mountainback 50 Miler (USA)                  50mi
# 3609803       Tussey Mountainback 50 Miler (USA)                  50mi
# 3609804       Tussey Mountainback 50 Miler (USA)                  50mi
# 3609805       Tussey Mountainback 50 Miler (USA)                  50mi
#
#          Event number of finishers Athlete performance         Athlete club  \
# 2538571                         38           7:34:19 h                  日本隊
# 2538572                         38           7:43:50 h                  NaN
# 2538573                         38           8:04:40 h                  NaN
# 2538574                         38           8:30:49 h            台灣大腳ㄚ長跑協會
# 2538575                         38           8:34:47 h                  NaN
# ...                            ...                 ...                  ...
# 3609801                         35          11:16:08 h  *Peachtree City, GA
# 3609802                         35          11:27:05 h         *Newport, PA
# 3609803                         35          11:46:34 h      *Flemington, NJ
# 3609804                         35          11:55:29 h       *Arlington, VA
# 3609805                         35          12:14:15 h       *Johnstown, PA
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 2538571             JPN                 1965.0              M
# 2538572             AUS                 1974.0              M
# 2538573             TPE                 1976.0              M
# 2538574             TPE                 1969.0              F
# 2538575             TPE                 1964.0              M
# ...                 ...                    ...            ...
# 3609801             USA                 1968.0              M
# 3609802             USA                 1959.0              M
# 3609803             USA                 1955.0              F
# 3609804             USA                 1965.0              M
# 3609805             USA                 1981.0              F
#
#         Athlete age category Athlete average speed  Athlete ID
# 2538571                  M50                10.627       53107
# 2538572                  M45                10.409        8785
# 2538573                  M40                 9.962        4502
# 2538574                  W50                 9.452       63964
# 2538575                  M55                 9.379        4485
# ...                      ...                   ...         ...
# 3609801                  M50                 7.141     1044739
# 3609802                  M60                 7.027       50971
# 3609803                  W65                 6.833       73152
# 3609804                  M55                 6.748      970133
# 3609805                  W40                 6.575      723380
#
# [272651 rows x 13 columns]

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)']['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 6417091    USA
# 6417092    USA
# 6417093    USA
# 6417094    USA
# 6417095    USA
# Name: Event name, Length: 338, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                                ...                   ...
# 7461181               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461182               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461183               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461184               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461185               Avalon Benefit 50-Mile Run (USA)                  50mi
#
#          Event number of finishers Athlete performance      Athlete club  \
# 55                               9           9:53:05 h  *Middleville, MI
# 56                               9          11:09:35 h     *Waterloo, ON
# 57                               9          11:33:00 h    *Kitchener, ON
# 58                               9          11:38:17 h        *Utica, MI
# 59                               9          11:56:35 h   *Grass Lake, MI
# ...                            ...                 ...               ...
# 7461181                         92          11:59:37 h               NaN
# 7461182                         92          12:01:41 h               NaN
# 7461183                         92          12:03:26 h               NaN
# 7461184                         92          12:03:26 h               NaN
# 7461185                         92          12:05:59 h               NaN
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 55                  USA                 1983.0              M
# 56                  CAN                 1977.0              F
# 57                  CAN                 1976.0              M
# 58                  USA                 1986.0              M
# 59                  USA                 1988.0              M
# ...                 ...                    ...            ...
# 7461181             USA                 1941.0              M
# 7461182             USA                 1932.0              M
# 7461183             USA                 1934.0              F
# 7461184             USA                 1951.0              F
# 7461185             USA                 1947.0              F
#
#         Athlete age category Athlete average speed  Athlete ID
# 55                       M23                 8.141          55
# 56                       W40                 7.211          56
# 57                       M40                 6.967          57
# 58                       M23                 6.914          58
# 59                       M23                 6.738          59
# ...                      ...                   ...         ...
# 7461181                  M50                6709.0     1045603
# 7461182                  M60                6690.0     1070463
# 7461183                  W60                6674.0      416139
# 7461184                  W40                6674.0     1098098
# 7461185                  W45                6650.0     1626367
#
# [1398540 rows x 13 columns]

# %%
# combine filters together
df[(df['Event distance/length'].isin(['50km', '50mi'])) & (df['Year of event'].isin([2020, 2021, 2022])) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 3609801           2022  16.10.2022
# 3609802           2022  16.10.2022
# 3609803           2022  16.10.2022
# 3609804           2022  16.10.2022
# 3609805           2022  16.10.2022
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...                                                ...                   ...
# 3609801             Tussey Mountainback 50 Miler (USA)                  50mi
# 3609802             Tussey Mountainback 50 Miler (USA)                  50mi
# 3609803             Tussey Mountainback 50 Miler (USA)                  50mi
# 3609804             Tussey Mountainback 50 Miler (USA)                  50mi
# 3609805             Tussey Mountainback 50 Miler (USA)                  50mi
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# 2539949                         20           4:27:34 h
# ...                            ...                 ...
# 3609801                         35          11:16:08 h
# 3609802                         35          11:27:05 h
# 3609803                         35          11:46:34 h
# 3609804                         35          11:55:29 h
# 3609805                         35          12:14:15 h
#
#                    Athlete club Athlete country  Athlete year of birth  \
# 2539945      *Normandy Park, WA             USA                 1991.0
# 2539946           *Gold Bar, WA             USA                 1981.0
# 2539947             *Vashon, WA             USA                 1999.0
# 2539948         *Gig Harbor, WA             USA                 1983.0
# 2539949  *Bainbridge Island, WA             USA                 1977.0
# ...                         ...             ...                    ...
# 3609801     *Peachtree City, GA             USA                 1968.0
# 3609802            *Newport, PA             USA                 1959.0
# 3609803         *Flemington, NJ             USA                 1955.0
# 3609804          *Arlington, VA             USA                 1965.0
# 3609805          *Johnstown, PA             USA                 1981.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2539945              M                  M23                15.158       71287
# 2539946              M                  M35                12.369      629508
# 2539947              M                 MU23                12.099       64838
# 2539948              M                  M35                11.449      704450
# 2539949              M                  M40                11.212      810281
# ...                ...                  ...                   ...         ...
# 3609801              M                  M50                 7.141     1044739
# 3609802              M                  M60                 7.027       50971
# 3609803              F                  W65                 6.833       73152
# 3609804              M                  M55                 6.748      970133
# 3609805              F                  W40                 6.575      723380
#
# [139032 rows x 13 columns]

# %%
df2 = df[(df['Event distance/length'].isin(['50km', '50mi'])) & (df['Year of event'].isin([2020, 2021, 2022])) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]

# %%
df2.shape
# Out:
# (139032, 13)

# %%
# Remove (USA) from event name

df2['Event name'].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 3609801               Tussey Mountainback 50 Miler
# 3609802               Tussey Mountainback 50 Miler
# 3609803               Tussey Mountainback 50 Miler
# 3609804               Tussey Mountainback 50 Miler
# 3609805               Tussey Mountainback 50 Miler
# Name: Event name, Length: 139032, dtype: object

# %%
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\chide\AppData\Local\Temp\ipykernel_14184\3473829760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
#                    Athlete club Athlete country  Athlete year of birth  \
# 2539945      *Normandy Park, WA             USA                 1991.0
# 2539946           *Gold Bar, WA             USA                 1981.0
# 2539947             *Vashon, WA             USA                 1999.0
# 2539948         *Gig Harbor, WA             USA                 1983.0
# 2539949  *Bainbridge Island, WA             USA                 1977.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2539945              M                  M23                15.158       71287
# 2539946              M                  M35                12.369      629508
# 2539947              M                 MU23                12.099       64838
# 2539948              M                  M35                11.449      704450
# 2539949              M                  M40                11.212      810281

# %%
# Clean the athlete age
df2['Athlete age'] = df2['Year of event'] - df2['Athlete year of birth']
# Out:
# C:\Users\chide\AppData\Local\Temp\ipykernel_14184\1275400649.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete age'] = df2['Year of event'] - df2['Athlete year of birth']

# %%
# Remove h from Athlete performance

df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\chide\AppData\Local\Temp\ipykernel_14184\746661769.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(3)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance        Athlete club  \
# 2539945                         20             3:17:55  *Normandy Park, WA
# 2539946                         20             4:02:32       *Gold Bar, WA
# 2539947                         20             4:07:57         *Vashon, WA
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 2539945             USA                 1991.0              M
# 2539946             USA                 1981.0              M
# 2539947             USA                 1999.0              M
#
#         Athlete age category Athlete average speed  Athlete ID  Athlete age
# 2539945                  M23                15.158       71287         29.0
# 2539946                  M35                12.369      629508         39.0
# 2539947                 MU23                12.099       64838         21.0

# %%
# drop columns: Athlete Club, Athlete Country, Athlete year of birth, Athlete Age Category

df2 = df2.drop(['Athlete club','Athlete country', 'Athlete year of birth', 'Athlete age category'], axis = 1)

# %%
df2.head(3)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance Athlete gender  \
# 2539945                         20             3:17:55              M
# 2539946                         20             4:02:32              M
# 2539947                         20             4:07:57              M
#
#         Athlete average speed  Athlete ID  Athlete age
# 2539945                15.158       71287         29.0
# 2539946                12.369      629508         39.0
# 2539947                12.099       64838         21.0

# %%
# clean null values

df2.isna().sum()
# Out:
# Year of event                   0
# Event dates                     0
# Event name                      0
# Event distance/length           0
# Event number of finishers       0
# Athlete performance             0
# Athlete gender                  0
# Athlete average speed           0
# Athlete ID                      0
# Athlete age                  2839
# dtype: int64

# %%
df2[df2['Athlete age'].isna() == 1]
# Out:
#          Year of event Event dates                            Event name  \
# 2547794           2020  25.01.2020    North Carolina Fat Ass 50 Km (USA)
# 2551331           2020  19.01.2020  Big Bend 50 - Fresno Creek 50K (USA)
# 2551336           2020  19.01.2020  Big Bend 50 - Fresno Creek 50K (USA)
# 2551344           2020  19.01.2020  Big Bend 50 - Fresno Creek 50K (USA)
# 2551348           2020  19.01.2020  Big Bend 50 - Fresno Creek 50K (USA)
# ...                ...         ...                                   ...
# 3601761           2022  22.10.2022      Lake Hodges Trail Fest 50K (USA)
# 3601768           2022  22.10.2022      Lake Hodges Trail Fest 50K (USA)
# 3601771           2022  22.10.2022      Lake Hodges Trail Fest 50K (USA)
# 3601774           2022  22.10.2022      Lake Hodges Trail Fest 50K (USA)
# 3601776           2022  22.10.2022      Lake Hodges Trail Fest 50K (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2547794                  50km                         57             6:10:30
# 2551331                  50km                         54             4:46:34
# 2551336                  50km                         54             5:08:36
# 2551344                  50km                         54             5:54:04
# 2551348                  50km                         54             6:07:11
# ...                       ...                        ...                 ...
# 3601761                  50km                        116             7:20:19
# 3601768                  50km                        116             7:30:35
# 3601771                  50km                        116             7:50:50
# 3601774                  50km                        116             8:00:28
# 3601776                  50km                        116             8:17:40
#
#         Athlete gender Athlete average speed  Athlete ID  Athlete age
# 2547794              M                 8.097      811923          NaN
# 2551331              M                10.469      812656          NaN
# 2551336              M                 9.721      812657          NaN
# 2551344              F                 8.473      658221          NaN
# 2551348              M                  8.17      812660          NaN
# ...                ...                   ...         ...          ...
# 3601761              M                 6.813       74573          NaN
# 3601768              F                 6.658     1043495          NaN
# 3601771              M                 6.372     1043497          NaN
# 3601774              M                 6.244     1043498          NaN
# 3601776              M                 6.028      816612          NaN
#
# [2839 rows x 10 columns]

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (136193, 10)

# %%
#check for duplicates
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athlete age]
# Index: []

# %%
#reset index
df2.reset_index(drop = True)
# Out:
#         Year of event Event dates  \
# 0                2020  02.02.2020
# 1                2020  02.02.2020
# 2                2020  02.02.2020
# 3                2020  02.02.2020
# 4                2020  02.02.2020
# ...               ...         ...
# 136188           2022  16.10.2022
# 136189           2022  16.10.2022
# 136190           2022  16.10.2022
# 136191           2022  16.10.2022
# 136192           2022  16.10.2022
#
#                                            Event name Event distance/length  \
# 0       West Seattle Beach Run - Winter Edition (USA)                  50km
# 1       West Seattle Beach Run - Winter Edition (USA)                  50km
# 2       West Seattle Beach Run - Winter Edition (USA)                  50km
# 3       West Seattle Beach Run - Winter Edition (USA)                  50km
# 4       West Seattle Beach Run - Winter Edition (USA)                  50km
# ...                                               ...                   ...
# 136188             Tussey Mountainback 50 Miler (USA)                  50mi
# 136189             Tussey Mountainback 50 Miler (USA)                  50mi
# 136190             Tussey Mountainback 50 Miler (USA)                  50mi
# 136191             Tussey Mountainback 50 Miler (USA)                  50mi
# 136192             Tussey Mountainback 50 Miler (USA)                  50mi
#
#         Event number of finishers Athlete performance Athlete gender  \
# 0                              20             3:17:55              M
# 1                              20             4:02:32              M
# 2                              20             4:07:57              M
# 3                              20             4:22:02              M
# 4                              20             4:27:34              M
# ...                           ...                 ...            ...
# 136188                         35            11:16:08              M
# 136189                         35            11:27:05              M
# 136190                         35            11:46:34              F
# 136191                         35            11:55:29              M
# 136192                         35            12:14:15              F
#
#        Athlete average speed  Athlete ID  Athlete age
# 0                     15.158       71287         29.0
# 1                     12.369      629508         39.0
# 2                     12.099       64838         21.0
# 3                     11.449      704450         37.0
# 4                     11.212      810281         43.0
# ...                      ...         ...          ...
# 136188                 7.141     1044739         54.0
# 136189                 7.027       50971         63.0
# 136190                 6.833       73152         67.0
# 136191                 6.748      970133         57.0
# 136192                 6.575      723380         41.0
#
# [136193 rows x 10 columns]

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# Athlete age                  float64
# dtype: object

# %%
df2['Athlete age'] = df2['Athlete age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# Athlete age                    int32
# dtype: object

# %%
df2.head()
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance Athlete gender  \
# 2539945                         20             3:17:55              M
# 2539946                         20             4:02:32              M
# 2539947                         20             4:07:57              M
# 2539948                         20             4:22:02              M
# 2539949                         20             4:27:34              M
#
#          Athlete average speed  Athlete ID  Athlete age
# 2539945                 15.158       71287           29
# 2539946                 12.369      629508           39
# 2539947                 12.099       64838           21
# 2539948                 11.449      704450           37
# 2539949                 11.212      810281           43

# %%
df2 = df2.rename(columns= {
                'Year of event': 'year',                  
                'Event dates': 'race_day',              
                'Event name': 'race_name',                    
                'Event distance/length': 'race_length',        
                'Event number of finishers': 'race_number_of_finisher',      
                'Athlete performance': 'athlete_performance',           
                'Athlete gender': 'athlete_gender',                
                'Athlete average speed': 'athlete_average_speed',         
                'Athlete ID': 'athlete_id',                   
                'Athlete age': 'athlete_age'
                })

# %%
df2.head(5)
# Out:
#          year    race_day                                      race_name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
#
#         race_length  race_number_of_finisher athlete_performance  \
# 2539945        50km                       20             3:17:55
# 2539946        50km                       20             4:02:32
# 2539947        50km                       20             4:07:57
# 2539948        50km                       20             4:22:02
# 2539949        50km                       20             4:27:34
#
#         athlete_gender  athlete_average_speed  athlete_id  athlete_age
# 2539945              M                 15.158       71287           29
# 2539946              M                 12.369      629508           39
# 2539947              M                 12.099       64838           21
# 2539948              M                 11.449      704450           37
# 2539949              M                 11.212      810281           43

# %%
#reset index
df2.reset_index(drop = True)
# Out:
#         year    race_day                                      race_name  \
# 0       2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 1       2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2       2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 3       2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 4       2020  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# ...      ...         ...                                            ...
# 136188  2022  16.10.2022             Tussey Mountainback 50 Miler (USA)
# 136189  2022  16.10.2022             Tussey Mountainback 50 Miler (USA)
# 136190  2022  16.10.2022             Tussey Mountainback 50 Miler (USA)
# 136191  2022  16.10.2022             Tussey Mountainback 50 Miler (USA)
# 136192  2022  16.10.2022             Tussey Mountainback 50 Miler (USA)
#
#        race_length  race_number_of_finisher athlete_performance  \
# 0             50km                       20             3:17:55
# 1             50km                       20             4:02:32
# 2             50km                       20             4:07:57
# 3             50km                       20             4:22:02
# 4             50km                       20             4:27:34
# ...            ...                      ...                 ...
# 136188        50mi                       35            11:16:08
# 136189        50mi                       35            11:27:05
# 136190        50mi                       35            11:46:34
# 136191        50mi                       35            11:55:29
# 136192        50mi                       35            12:14:15
#
#        athlete_gender  athlete_average_speed  athlete_id  athlete_age
# 0                   M                 15.158       71287           29
# 1                   M                 12.369      629508           39
# 2                   M                 12.099       64838           21
# 3                   M                 11.449      704450           37
# 4                   M                 11.212      810281           43
# ...               ...                    ...         ...          ...
# 136188              M                  7.141     1044739           54
# 136189              M                  7.027       50971           63
# 136190              F                  6.833       73152           67
# 136191              M                  6.748      970133           57
# 136192              F                  6.575      723380           41
#
# [136193 rows x 10 columns]

# %%
df3 = df2[['race_day', 'race_name', 'race_length', 'race_number_of_finisher', 'athlete_id', 'athlete_gender', 'athlete_age', 'athlete_performance', 'athlete_average_speed', 'year' ]]

# %%
df3.head(3)
# Out:
#            race_day                                      race_name  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
#
#         race_length  race_number_of_finisher  athlete_id athlete_gender  \
# 2539945        50km                       20       71287              M
# 2539946        50km                       20      629508              M
# 2539947        50km                       20       64838              M
#
#          athlete_age athlete_performance  athlete_average_speed  year
# 2539945           29             3:17:55                 15.158  2020
# 2539946           39             4:02:32                 12.369  2020
# 2539947           21             4:07:57                 12.099  2020

# %%
# Plot race length

sns.histplot(df3['race_length'])
# Out:
# C:\Users\chide\anaconda3\envs\myvenv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df3, x = 'race_length', hue='athlete_gender')
# Out:
# C:\Users\chide\anaconda3\envs\myvenv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\chide\anaconda3\envs\myvenv\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\chide\anaconda3\envs\myvenv\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\chide\anaconda3\envs\myvenv\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\chide\anaconda3\envs\myvenv\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\chide\anaconda3\envs\myvenv\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df3[df3['race_length'] == '50mi']['athlete_average_speed'])
# Out:
# C:\Users\chide\anaconda3\envs\myvenv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.violinplot(data = df3, x='race_length', y='athlete_average_speed', hue='athlete_gender', inner ='quart', linewidth=1)
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data=df3, x='athlete_age', y='athlete_average_speed', hue='athlete_gender')

# %%
# Find the difference in speed for the 50km, 50mi male, female, X
df3.groupby(['race_length', 'athlete_gender'])['athlete_average_speed']
   .mean()
# Out:
# race_length  athlete_gender
# 50km         F                 6.937634
#              M                 7.564819
#              X                 6.971167
# 50mi         F                 6.787705
#              M                 7.224409
# Name: athlete_average_speed, dtype: float64

# %%
#Age groups best in the 50m Race 
df3.query('race_length == "50mi"')\
    .groupby('athlete_age')['athlete_average_speed']\
    .agg(['mean', 'count'])\
    .sort_values('mean', ascending=False)\
    .query('count>19')
# Out:
#                  mean  count
# athlete_age
# 20           7.675809    136
# 26           7.641463    568
# 19           7.605209     91
# 24           7.576395    390
# 21           7.528902    194
# 25           7.511123    497
# 29           7.480024    865
# 28           7.468432    702
# 30           7.455244    852
# 23           7.442270    344
# 31           7.425465    890
# 22           7.413872    235
# 32           7.407643    962
# 34           7.359162   1037
# 27           7.339797    627
# 37           7.314887   1173
# 38           7.277005   1218
# 35           7.263548   1056
# 36           7.250561   1158
# 39           7.244994   1251
# 33           7.209563    982
# 17           7.122710     31
# 40           7.122061   1301
# 44           7.073303   1066
# 42           7.067701   1234
# 43           7.050370   1100
# 41           7.045428   1284
# 45           7.016157   1028
# 46           6.961431    994
# 47           6.917584    941
# 49           6.909255    825
# 18           6.894478     46
# 57           6.886735    396
# 48           6.870689    874
# 53           6.856581    635
# 50           6.788742    939
# 51           6.786243    775
# 54           6.761058    565
# 56           6.753819    420
# 52           6.750155    673
# 55           6.730203    458
# 58           6.654656    337
# 59           6.545272    390
# 63           6.495062    192
# 61           6.467112    241
# 62           6.455216    232
# 60           6.412529    306
# 64           6.308948    155
# 66           6.195025     79
# 65           6.126651    106
# 67           6.117681     72
# 69           5.997102     49
# 71           5.921719     32
# 70           5.864366     41
# 72           5.791632     38
# 68           5.778048     63
# 73           5.583433     30

# %%
#Age groups worst in the 50m Race 
df3.query('race_length == "50mi"')\
    .groupby('athlete_age')['athlete_average_speed']\
    .agg(['mean', 'count'])\
    .sort_values('mean', ascending=True)\
    .query('count>9')
# Out:
#                  mean  count
# athlete_age
# 79           5.218583     12
# 74           5.355579     19
# 73           5.583433     30
# 68           5.778048     63
# 72           5.791632     38
# ...               ...    ...
# 21           7.528902    194
# 24           7.576395    390
# 19           7.605209     91
# 26           7.641463    568
# 20           7.675809    136
#
# [61 rows x 2 columns]

# %%
# Seasons for the data -
# spring 
# Summer
# fall
# winter 

df3['race_month'] = df3['race_day'].str.split('.').str.get(1).astype(int)
# Out:
# C:\Users\chide\AppData\Local\Temp\ipykernel_14184\3794047233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['race_month'] = df3['race_day'].str.split('.').str.get(1).astype(int)

# %%
df3.head(5)
# Out:
#            race_day                                      race_name  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
#
#         race_length  race_number_of_finisher  athlete_id athlete_gender  \
# 2539945        50km                       20       71287              M
# 2539946        50km                       20      629508              M
# 2539947        50km                       20       64838              M
# 2539948        50km                       20      704450              M
# 2539949        50km                       20      810281              M
#
#          athlete_age athlete_performance  athlete_average_speed  year  \
# 2539945           29             3:17:55                 15.158  2020
# 2539946           39             4:02:32                 12.369  2020
# 2539947           21             4:07:57                 12.099  2020
# 2539948           37             4:22:02                 11.449  2020
# 2539949           43             4:27:34                 11.212  2020
#
#          race_month
# 2539945           2
# 2539946           2
# 2539947           2
# 2539948           2
# 2539949           2

# %%
df3['race_season'] = df3['race_month'].apply(lambda x: 'Winter' if x > 11 else 'Fall' if x > 8 else 'Summer' if x > 5  else 'Spring' if x > 2 else 'Winter')
# Out:
# C:\Users\chide\AppData\Local\Temp\ipykernel_14184\1360873473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['race_season'] = df3['race_month'].apply(lambda x: 'Winter' if x > 11 else 'Fall' if x > 8 else 'Summer' if x > 5  else 'Spring' if x > 2 else 'Winter')

# %%
df3.head(3)
# Out:
#            race_day                                      race_name  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
#
#         race_length  race_number_of_finisher  athlete_id athlete_gender  \
# 2539945        50km                       20       71287              M
# 2539946        50km                       20      629508              M
# 2539947        50km                       20       64838              M
#
#          athlete_age athlete_performance  athlete_average_speed  year  \
# 2539945           29             3:17:55                 15.158  2020
# 2539946           39             4:02:32                 12.369  2020
# 2539947           21             4:07:57                 12.099  2020
#
#          race_month race_season
# 2539945           2      Winter
# 2539946           2      Winter
# 2539947           2      Winter

# %%
df3.groupby('race_season')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False)
# Out:
#                  mean  count
# race_season
# Winter       7.396737  32938
# Fall         7.327056  42539
# Spring       7.318784  34339
# Summer       7.033403  26377

# %%
df3.query('race_length == "50mi"').groupby('race_season')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False)
# Out:
#                  mean  count
# race_season
# Fall         7.443876   9938
# Spring       7.141417   8338
# Winter       6.872288   8144
# Summer       6.797440   6854
